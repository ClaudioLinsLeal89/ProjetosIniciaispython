# %% [markdown]
# ### Testes

# %%
import pyodbc
import pandas as pd
import numpy as np

conexao = pyodbc.connect('Driver={SQL Server};'
                'Server=CURIAIA1-10-3\FINANCEIRO_PRD;'
                'Database=DW_SFCRI;'
                'Trusted_Connection=yes;')

cursor = conexao.cursor()

######################################################

selecionar_SQL = f"""SELECT * FROM [DW_SFCRI].[TESOURARIA].[APLICACAO_FUNDOS]"""

df_aplicacao = pd.read_sql_query(selecionar_SQL, conexao)

df_aplicacao
# Out:
# C:\Users\claudio.leal\AppData\Local\Temp\ipykernel_3096\311263938.py:16: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_versao_orcamento = pd.read_sql_query(selecionar_SQL, conexao)
#               TIPO         APLICACAO       DATA  CDI_100%  FATOR_DIARIO  \
# 0           FUNDOS  CEF_FXINGU_BNDES 2020-10-31  1.000075      1.000084
# 1           FUNDOS  CEF_FXINGU_BNDES 2020-11-03  1.000075      1.000084
# 2           FUNDOS  CEF_FXINGU_BNDES 2020-11-04  1.000075      1.000084
# 3           FUNDOS  CEF_FXINGU_BNDES 2020-11-05  1.000075      1.000084
# 4           FUNDOS  CEF_FXINGU_BNDES 2020-11-06  1.000075      1.000084
# ...            ...               ...        ...       ...           ...
# 125633  APLICACOES    ITAU_061023_80 2023-10-27  1.000473      1.000378
# ...

# %% [markdown]
# ### Teste 2

# %%
import win32com.client as win32
 
# criar a integração com o outlook
outlook = win32.Dispatch('outlook.application')

# criar um email
email = outlook.CreateItem(0)

# faturamento = 1500
# qtde_produtos = 10
# ticket_medio = faturamento / qtde_produtos

# configurar as informações do seu e-mail
# email.To = "leandroalves@norteenergiasa.com.br; lyon10x.bsbdf10@gmail.com; leandro.bsbdf10@gmail.com"
email.To = "claudioleal@norteenergiasa.com.br;"

# email.To = "pythonimpressionador@gmail.com; pythonimpressionador+lira@gmail.com"
email.Subject = "E-mail automático do Python"
email.HTMLBody = f"""

<p>Carga de controle de aplicações carregada no SQL</p>
<p>Dados com movimentações 20/10/2023. </p>
<p>Abs,</p>
<p>Código Python</p>

"""

# anexo1 = r"C:\Users\leandro.alves\Norte Energia\orcamento - General\6 - Diversos\Teste CSV\Fechamento Fevereiro2023.xlsx"

# email.Attachments.Add(anexo1)

# anexo2 = r"C:\Users\leandro.alves\Documents\GitHub\Python_Scripts\script_atualizar_base\arquivos_testes\IPCA_ACM.xlsx"

# email.Attachments.Add(anexo2)

 
# enviar e-mail
email.Send()

print("Email Enviado")
# Out:
# Email Enviado
